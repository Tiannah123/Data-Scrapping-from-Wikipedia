# %%
import pandas as pd

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_highest-grossing_films')
tables
# Out:
# [    Rank  Peak                                          Title  \
#  0      1     1                                         Avatar
#  1      2     1                              Avengers: Endgame
#  2      3     3                       Avatar: The Way of Water
#  3      4     1                                        Titanic
#  4      5     3                   Star Wars: The Force Awakens
#  5      6     4                         Avengers: Infinity War
#  6      7     6                        Spider-Man: No Way Home
#  7      8     3                                 Jurassic World
#  8      9     7                                  The Lion King
#  9     10    10                                 Inside Out 2 †
#  10    11     3                                   The Avengers
#  11    12     4                                      Furious 7
#  12    13    11                              Top Gun: Maverick
#  13    14    10                                      Frozen II
# ...

# %%
df = tables[0]
df
# Out:
#     Rank  Peak                                          Title  \
# 0      1     1                                         Avatar
# 1      2     1                              Avengers: Endgame
# 2      3     3                       Avatar: The Way of Water
# 3      4     1                                        Titanic
# 4      5     3                   Star Wars: The Force Awakens
# 5      6     4                         Avengers: Infinity War
# 6      7     6                        Spider-Man: No Way Home
# 7      8     3                                 Jurassic World
# 8      9     7                                  The Lion King
# 9     10    10                                 Inside Out 2 †
# 10    11     3                                   The Avengers
# 11    12     4                                      Furious 7
# 12    13    11                              Top Gun: Maverick
# 13    14    10                                      Frozen II
# ...

# %%
print(df.columns)
# Out:
# Index(['Rank', 'Peak', 'Title', 'Worldwide gross', 'Year', 'Ref'], dtype='object')

# %%
df = df.drop(columns = ['Ref'])

# %%
print(df.columns)
# Out:
# Index(['Rank', 'Peak', 'Title', 'Worldwide gross', 'Year'], dtype='object')

# %%
df
# Out:
#     Rank  Peak                                          Title  \
# 0      1     1                                         Avatar
# 1      2     1                              Avengers: Endgame
# 2      3     3                       Avatar: The Way of Water
# 3      4     1                                        Titanic
# 4      5     3                   Star Wars: The Force Awakens
# 5      6     4                         Avengers: Infinity War
# 6      7     6                        Spider-Man: No Way Home
# 7      8     3                                 Jurassic World
# 8      9     7                                  The Lion King
# 9     10    10                                 Inside Out 2 †
# 10    11     3                                   The Avengers
# 11    12     4                                      Furious 7
# 12    13    11                              Top Gun: Maverick
# 13    14    10                                      Frozen II
# ...

# %%
df.to_csv(r'C:\Users\USER\Downloads\data.csv', index = False)
